# %% [markdown]
# #Evaluasi CPMK 1 dan

# %% [markdown]
# # Soal 1

# %% [markdown]
# <br>1.CPMK1- Sub CPMK1.1( bobot : 10 )
# <br>Lakukan crawling data teks dari media sosial/ web dan simpan hasilnya dalam bentuk excel/csv.
# <br>Setiap mahasiswa harus melakukan crawling dengan kata kunci tertentu.
# <br>Kata kunci tidak boleh sama dengan mahasiswa lainnya.

# %%
from google_play_scraper import Sort, reviews, app
import pandas as pd
import numpy as np

# %%
result, continuation_token = reviews(
    'com.ss.android.ugc.trill',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=1000,
    filter_score_with=None
)

# %%
data = pd.DataFrame(np.array(result), columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))

# %%
reset = data['score'].value_counts().reset_index()
reset.columns = ['score', 'Counts']
reset = reset.sort_values(by='score')
reset
# Out:
#    score  Counts
# 0      1     577
# 1      2     209
# 2      3     119
# 4      4      36
# 3      5      59

# %%
df = pd.DataFrame(data[['userName', 'content', 'score']])

# %%
df
# Out:
#                            userName  \
# 0    Isi Ref GBHTXZ6QRXYZU dptbonus
# 1           Manisa Agustin (Nagstd)
# 2                  Irma Wiji astuti
# 3                 Dani Tri setiawan
# 4                     Luffi Mangure
# ..                              ...
# 995                     raffi irham
# 996                   Richard Saduk
# 997                      Mustari 94
# 998             Agata cornelia Pidu
# 999            Salsabila Santika f.
#
#                                                content  score
# 0    Kombinasi konten kreator nya sangat lah menari...      3
# 1    subtitle terjemah di tiktok sekarang ilang, da...      2
# 2    TOLONG DI PERBAIKI DAN D PERHATIKAN . Akhir2 i...      3
# 3    aplikasi jelek, masa kalo mau liat tiktok masu...      1
# 4    Ada banyak hal menarik bisa kita dapatkan deng...      2
# ..                                                 ...    ...
# 995  ada apakah dengan tiktok sekarang cape, keluar...      1
# ...

# %%
df.to_csv('crawling_play_store.csv', index=True)

# %% [markdown]
# # Soal 2

# %% [markdown]
# <br>Lakukan pembersihan meliputi penghapusan punctuation, angka dan karakter yang tidak penting menggunakan menggunakan regex.
# <br>Simpan hasilnya menjadi file csv/excel.

# %%
import re

# %%
def clean_text(df):
    text = re.sub(r'\d+', '', text)
    text = re.sub(f'[{re.escape(string.punctuation)}]', '', text)
    text = re.sub(r'[^a-zA-Z\s]', ' ', text)
    text = ' '.join(text.split())
    return text

print(df['content'])
# Out:
# 0      Kombinasi konten kreator nya sangat lah menari...
# 1      subtitle terjemah di tiktok sekarang ilang, da...
# 2      TOLONG DI PERBAIKI DAN D PERHATIKAN . Akhir2 i...
# 3      aplikasi jelek, masa kalo mau liat tiktok masu...
# 4      Ada banyak hal menarik bisa kita dapatkan deng...
#                              ...
# 995    ada apakah dengan tiktok sekarang cape, keluar...
# 996    Setelah update gak bisa buka apk nya.. Harus d...
# 997    Sangat membantu untuk menambah cari cuan bagi ...
# 998    Akhir-akhir ini,Tik Tok sudah sering Error Say...
# 999    hai, kenapa ya sekarang tik tok makin susah bu...
# Name: content, Length: 1000, dtype: object

# %%
df['content'].to_csv('regex.csv', index=True)

# %% [markdown]
# # Soal 3a

# %% [markdown]
# a.	Lakukan parsing dan simpan hasilnya dalam bentuk excel/csv (bobot:10)

# %% [markdown]
# # Soal 3b

# %% [markdown]
# b.Carilah kata-kata slangword yang ada dalam dataset Anda, dengan cara mencocokan dengan kamus KBBI (terlampir).
# <br>Simpan hasilnya dalam bentuk csv/excel.
# <br> Tampilkan 100 kata slang yang Anda dapatkan dan tampilkan dalam bentuk Gunakan (bobot:25)

# %%
import pandas as pd

slangwords_df = pd.read_csv('stopwords.csv')

def find_slang(text):
    slangwords = list(slangwords_df['Slangwords'])
    found_slang = []
    for word in text.split():
        if word in slangwords:
            found_slang.append(word)
    return found_slang

df['content'] = df['content'].apply(find_slang)

print(df)
# Out:
#                            userName  \
# 0    Isi Ref GBHTXZ6QRXYZU dptbonus
# 1           Manisa Agustin (Nagstd)
# 2                  Irma Wiji astuti
# 3                 Dani Tri setiawan
# 4                     Luffi Mangure
# ..                              ...
# 995                     raffi irham
# 996                   Richard Saduk
# 997                      Mustari 94
# 998             Agata cornelia Pidu
# 999            Salsabila Santika f.
#
#                                                content  score
# 0    [kreator, sangat, lah, menarik, dan, terlihat,...      3
# 1    [terjemah, di, sekarang, dan, harus, di, secar...      2
# 2    [ini, sering, kadang, bisa, muncul, logo, kada...      3
# 3    [aplikasi, masa, kalo, mau, liat, lama, coba, ...      1
# 4    [banyak, hal, menarik, bisa, kita, dengan, men...      2
# ..                                                 ...    ...
# 995  [ada, apakah, dengan, sekarang, keluar, hanya,...      1
# ...

# %% [markdown]
# # Soal 3c

# %% [markdown]
# c.Lakukan tokenizing berdasarkan  hasil 3b, simpan hasilnya dalam bentuk csv/excel  dan tampilkan 100 token pertama. (bobot:10)

# %%
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize

def tokenize_sentences(text):
    sentences = sent_tokenize(text)
    return sentences

df['content'] = df['content'].apply(lambda x: tokenize_sentences(x))

print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 9
#       6     sentences = sent_tokenize(text)
#       7     return sentences
# ----> 9 df['content'] = df['content'].apply(lambda x: tokenize_sentences(x))
#      11 print(df)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
# ...

# %% [markdown]
# # Soal 3d

# %% [markdown]
# d.Lakukan stopword removing  berdasarkan hasil 3c, simpan hasilnya dalam bentuk csv/excel. (bobot:10)!

# %%
from nltk.corpus import stopwords

# %%
stopwords = stopwords.words('indonesian')
stopwords
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
# ...

# %% [markdown]
# # Soal 3e

# %% [markdown]
# e.Lakukan stemming berdasarkan hasil 3d dan tampilkan 100 stem pertama. (bobot:10)
